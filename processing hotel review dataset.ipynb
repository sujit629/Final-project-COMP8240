# %%
import pandas as pd

# Specify the path to your CSV file
csv_file_path = r"C:\Users\Sujit\Downloads\Datafiniti_Hotel_Reviews\Datafiniti_Hotel_Reviews.csv"

# Read the CSV file into a pandas DataFrame
df = pd.read_csv(csv_file_path)

# %%
df.head()
# Out:
#                      id             dateAdded           dateUpdated  \
# 0  AVwc252WIN2L1WUfpqLP  2016-10-30T21:42:42Z  2018-09-10T21:06:27Z
# 1  AVwc252WIN2L1WUfpqLP  2016-10-30T21:42:42Z  2018-09-10T21:06:27Z
# 2  AVwc252WIN2L1WUfpqLP  2016-10-30T21:42:42Z  2018-09-10T21:06:27Z
# 3  AVwdOclqIN2L1WUfti38  2015-11-28T19:19:35Z  2018-09-10T21:06:16Z
# 4  AVwdOclqIN2L1WUfti38  2015-11-28T19:19:35Z  2018-09-10T21:06:16Z
#
#              address                                         categories  \
# 0  5921 Valencia Cir  Hotels,Hotels and motels,Hotel and motel reser...
# 1  5921 Valencia Cir  Hotels,Hotels and motels,Hotel and motel reser...
# 2  5921 Valencia Cir  Hotels,Hotels and motels,Hotel and motel reser...
# 3     7520 Teague Rd  Hotels,Hotels and motels,Travel agencies and b...
# 4     7520 Teague Rd  Hotels,Hotels and motels,Travel agencies and b...
#
#                primaryCategories             city country  \
# 0  Accommodation & Food Services  Rancho Santa Fe      US
# ...

# %%
df = df.drop(columns=['id','dateAdded','dateUpdated','address','categories','primaryCategories','city','country','keys','latitude','longitude','name','postalCode','province','reviews.date','reviews.dateSeen','reviews.sourceURLs','reviews.title','reviews.userCity','reviews.userProvince','reviews.username','sourceURLs','websites'])

# %%
df.head()
# Out:
#    reviews.rating                                       reviews.text
# 0             5.0  Our experience at Rancho Valencia was absolute...
# 1             5.0  Amazing place. Everyone was extremely warm and...
# 2             5.0  We booked a 3 night stay at Rancho Valencia to...
# 3             2.0  Currently in bed writing this for the past hr ...
# 4             5.0  I live in Md and the Aloft is my Home away fro...

# %%
# Function to set labels for review ratings
def set_label(review_rating):
    if 1.00 <= review_rating <= 2.50:
        return 0
    elif 2.50 < review_rating <= 5.00:
        return 1
    else:
        return None

# %%
# Apply the set_label function to the 'reviews.rating' column and create a new 'label' column
df['label'] = df['reviews.rating'].apply(set_label)

# Print the DataFrame to see the new 'label' column
print(df)
# Out:
#       reviews.rating                                       reviews.text  label
# 0                5.0  Our experience at Rancho Valencia was absolute...      1
# 1                5.0  Amazing place. Everyone was extremely warm and...      1
# 2                5.0  We booked a 3 night stay at Rancho Valencia to...      1
# 3                2.0  Currently in bed writing this for the past hr ...      0
# 4                5.0  I live in Md and the Aloft is my Home away fro...      1
# ...              ...                                                ...    ...
# 9995             3.0  It is hard for me to review an oceanfront hote...      1
# 9996             4.0  I live close by, and needed to stay somewhere ...      1
# 9997             4.0  Rolled in 11:30 laid out heads down woke up to...      1
# 9998             1.0  Absolutely terrible..I was told I was being gi...      0
# 9999             1.0  Filthy, outdated, noisy neighbours, but this w...      0
#
# ...

# %%
# Out:
#    reviews.rating                                       reviews.text
# 0             5.0  Our experience at Rancho Valencia was absolute...
# 1             5.0  Amazing place. Everyone was extremely warm and...
# 2             5.0  We booked a 3 night stay at Rancho Valencia to...
# 3             2.0  Currently in bed writing this for the past hr ...
# 4             5.0  I live in Md and the Aloft is my Home away fro...

# %%
# Function to set labels for review ratings
def set_label(review_rating):
    if 1.00 <= review_rating <= 2.50:
        return 0
    elif 2.50 < review_rating <= 5.00:
        return 1
    else:
        return None  # Handle ratings outside the specified range

# %%
# Apply the set_label function to the 'reviews.rating' column and create a new 'label' column
df['label'] = df['reviews.rating'].apply(set_label)

# Print the DataFrame to see the new 'label' column
print(df)
# Out:
#       reviews.rating                                       reviews.text  label
# 0                5.0  Our experience at Rancho Valencia was absolute...      1
# 1                5.0  Amazing place. Everyone was extremely warm and...      1
# 2                5.0  We booked a 3 night stay at Rancho Valencia to...      1
# 3                2.0  Currently in bed writing this for the past hr ...      0
# 4                5.0  I live in Md and the Aloft is my Home away fro...      1
# ...              ...                                                ...    ...
# 9995             3.0  It is hard for me to review an oceanfront hote...      1
# 9996             4.0  I live close by, and needed to stay somewhere ...      1
# 9997             4.0  Rolled in 11:30 laid out heads down woke up to...      1
# 9998             1.0  Absolutely terrible..I was told I was being gi...      0
# 9999             1.0  Filthy, outdated, noisy neighbours, but this w...      0
#
# ...

# %%
df.head()
# Out:
#    reviews.rating                                       reviews.text  label
# 0             5.0  Our experience at Rancho Valencia was absolute...      1
# 1             5.0  Amazing place. Everyone was extremely warm and...      1
# 2             5.0  We booked a 3 night stay at Rancho Valencia to...      1
# 3             2.0  Currently in bed writing this for the past hr ...      0
# 4             5.0  I live in Md and the Aloft is my Home away fro...      1

# %%
df = df.drop(columns=['reviews.rating'])

# %%
df = df.drop(columns=['reviews.rating'])

# %%
df.head()
# Out:
#                                         reviews.text  label
# 0  Our experience at Rancho Valencia was absolute...      1
# 1  Amazing place. Everyone was extremely warm and...      1
# 2  We booked a 3 night stay at Rancho Valencia to...      1
# 3  Currently in bed writing this for the past hr ...      0
# 4  I live in Md and the Aloft is my Home away fro...      1

# %%
# Specify the path where you want to save the new CSV file
output_csv_path = r"C:\Users\Sujit\Documents\hotel_reviews_label.csv"

# Save the DataFrame to a new CSV file
df.to_csv(output_csv_path, index=False)  # Set index to False to exclude the index column

print(f"DataFrame saved to {output_csv_path}")
# Out:
# DataFrame saved to C:\Users\Sujit\Documents\hotel_reviews_label.csv
